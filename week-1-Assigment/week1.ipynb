# %%
# importing pandas
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Loading the data

# %%
#loading the data from the csv file to a data frame 
df=pd.read_csv('data.csv')

# %% [markdown]
# Exploring data

# %%
#exploring data 

#displays first 5 rows
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %%
#display last 5 rows
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
#                                                 images  ...  \
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...                 NaN
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...                 NaN
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                 sizes  \
# 995             NaN  [{"size":"Onesize"}]
# 996             NaN  [{"size":"Onesize"}]
# 997             NaN  [{"size":"Onesize"}]
# 998  Tru███m R███il  [{"size":"Onesize"}]
# 999             NaN   [{"size":"Medium"}]
#
#                                                 videos  \
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                     seller_information  \
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                NaN
#
#                     variations  \
# 995                        NaN
# 996                        NaN
# 997  [{},{},{},{},{},{},{},{}]
# 998                        NaN
# 999              [{},{},{},{}]
#
#                                             best_offer  \
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [5 rows x 24 columns]

# %%
#random rows from the dataset 
df.sample(10)
# Out:
#      product_id           title  \
# 663    18942852          FITINC
# 757    18337610        Roadster
# 203    22585502        Nimidiya
# 150    21242962  Tommy Hilfiger
# 634    13722850        Roadster
# 471    14325388           Anouk
# 776    18830500      White Snow
# 750    14280286         Harvard
# 536    16287694      Saree mall
# 313    21421918          Baggit
#
#                                    product_description  rating  ratings_count  \
# 663  Women Blue Skinny Fit High-Rise Training or Gy...     4.4             14
# 757                Men Navy Blue Self-Striped Cardigan     4.3             32
# 203                      Ethnic Motifs Printed Dupatta     0.0              0
# 150  Sustainable Pure Cotton Denim Shirt Dress With...     4.4              9
# 634  X Discovery Adventures Women Olive Green Opaqu...     4.4             39
# 471  Women Peach-Coloured Pure Cotton Ethnic Motifs...     4.1             99
# 776        Girls Beige Heart Printed Hooded Sweatshirt     4.2             10
# 750  Men Grey Melange Acrylic Chevron Pattern Pullover     3.3             54
# 536            Brown Floral Linen Blend Banarasi Saree     0.0              0
# 313                              Textured Handheld Bag     4.6             18
#
#      initial_price  discount  final_price currency  \
# 663            999      55.0    "₹449.00"      INR
# 757           2299      67.0    "₹758.00"      INR
# 203            999      60.0    "₹399.00"      INR
# 150           5999      40.0  "₹5,699.00"      INR
# 634           1999      50.0    "₹999.00"      INR
# 471           2899       NaN  "₹2,899.00"      INR
# 776           1599      60.0  "₹1,599.00"      INR
# 750           1999       NaN  "₹1,999.00"      INR
# 536           4099      72.0  "₹1,147.00"      INR
# 313           1890      46.0  "₹1,039.00"      INR
#
#                                                 images  ...  \
# 663  http://assets.myntassets.com/assets/images/189...  ...
# 757  http://assets.myntassets.com/assets/images/183...  ...
# 203  http://assets.myntassets.com/assets/images/225...  ...
# 150  http://assets.myntassets.com/assets/images/212...  ...
# 634  http://assets.myntassets.com/assets/images/137...  ...
# 471  http://assets.myntassets.com/assets/images/143...  ...
# 776  http://assets.myntassets.com/assets/images/188...  ...
# 750  http://assets.myntassets.com/assets/images/142...  ...
# 536  http://assets.myntassets.com/assets/images/162...  ...
# 313  http://assets.myntassets.com/assets/images/214...  ...
#
#                                        amount_of_stars  \
# 663  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 757  {"1_star":2,"2_stars":1,"3_stars":2,"4_stars":...
# 203  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 150  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 634  {"1_star":0,"2_stars":0,"3_stars":6,"4_stars":...
# 471  {"1_star":9,"2_stars":3,"3_stars":10,"4_stars"...
# 776  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 750  {"1_star":16,"2_stars":1,"3_stars":10,"4_stars...
# 536  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 313  {"1_star":0,"2_stars":1,"3_stars":1,"4_stars":...
#
#                                    what_customers_said  \
# 663                                                NaN
# 757  [{"percentage":"100","value_name":"Fit, Just R...
# 203                                                NaN
# 150  [{"percentage":"50","value_name":"Fit, A Littl...
# 634                                                NaN
# 471  [{"percentage":"88","value_name":"Fit, Just Ri...
# 776                                                NaN
# 750  [{"percentage":"50","value_name":"Fit, Just Ri...
# 536                                                NaN
# 313                                                NaN
#
#                            seller_name  \
# 663  Fit███ Ap███els█████████Lim██████
# 757                 Tru███t C███erc███
# 203              PRE███TI ███LEC██████
# 150                 Fla███ech███tai███
# 634                 Tru███t C███erc███
# 471                                NaN
# 776                                NaN
# 750                                NaN
# 536  AAR███LIF███YLE█████████LIM██████
# 313                       Sup███om ███
#
#                                                  sizes  \
# 663  [{"size":"28","value":"28.0in","value_name":"T...
# 757  [{"size":"S","value":"37.0in","value_name":"Ch...
# 203                               [{"size":"Onesize"}]
# 150  [{"size":"XXS","value":"30.5in","value_name":"...
# 634  [{"size":"XS","value":"36.0in","value_name":"B...
# 471  [{"size":"XS","value":"32.0in","value_name":"T...
# 776  [{"size":"3-4Y","value":"27.0in","value_name":...
# 750  [{"size":"S","value":"39.0in","value_name":"Ch...
# 536                               [{"size":"Onesize"}]
# 313                                     [{"size":"M"}]
#
#                                                 videos  \
# 663                                                NaN
# 757  ["rw-18337610_cae700","https://videos.myntasse...
# 203                                                NaN
# 150                             ["rw-21242962_cae700"]
# 634                                                NaN
# 471                             ["rw-14325388_cae700"]
# 776  ["https://videos.myntassets.com/assets/videos/...
# 750  ["rw-14280286_cae700","https://videos.myntasse...
# 536                                                NaN
# 313  ["rw-21421918_cae700","https://videos.myntasse...
#
#                                     seller_information  \
# 663  GRO███ FL███, K█████████2, ███████████████████...
# 757  1 s███loo███Cab█████████-01███████████████████...
# 203         10,███rac███ ro█████████ GU███████████████
# 150  3rd███165███th █████████, s███████████████████...
# 634  1 s███loo███Cab█████████-01███████████████████...
# 471                                                NaN
# 776                                                NaN
# 750                                                NaN
# 536  B-4███,40███402█████████36,███████████████████...
# 313  Plo███o- ███ 1s█████████Sui███████████████████...
#
#                     variations  \
# 663                        NaN
# 757                 [{},{},{}]
# 203  [{},{},{},{},{},{},{},{}]
# 150                        NaN
# 634                        NaN
# 471                        NaN
# 776                        NaN
# 750                       [{}]
# 536           [{},{},{},{},{}]
# 313                    [{},{}]
#
#                                             best_offer  \
# 663  {"applicable_on":"Orders above Rs. 649 (only o...
# 757  {"applicable_on":"Orders above Rs. 749 (only o...
# 203  {"applicable_on":"Orders above Rs. 649 (only o...
# 150  {"applicable_on":"Purchase of 3 or more items"...
# 634                                                 {}
# 471                                                 {}
# 776                                                 {}
# 750                                                 {}
# 536  {"applicable_on":"Orders above Rs. 1499 (only ...
# 313  {"applicable_on":"Orders above Rs. 999 (only o...
#
#                                            more_offers     category
# 663  [{"offer_name":"10% Instant Discount on IndusI...       shorts
# 757  [{"offer_name":"10% Instant Discount on IndusI...     sweaters
# 203  [{"offer_name":"10% Instant Discount on IndusI...      dupatta
# 150  [{"offer_name":"10% Instant Discount on IndusI...      dresses
# 634  [{"offer_name":"10% Instant Discount on Citi C...       shirts
# 471  [{"offer_name":"10% Instant Discount on Citi C...   kurta-sets
# 776  [{"offer_name":"10% Instant Discount on Citi C...  sweatshirts
# 750  [{"offer_name":"10% Instant Discount on Citi C...     sweaters
# 536  [{"offer_name":"10% Instant Discount on IndusI...       sarees
# 313  [{"offer_name":"10% Instant Discount on IndusI...     handbags
#
# [10 rows x 24 columns]

# %%
# no of rows and columns in the data set
df.shape
# Out:
# (1000, 24)

# %%
#structural summary of the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
#  14  amount_of_stars         1000 non-null   object
#  15  what_customers_said     427 non-null    object
#  16  seller_name             699 non-null    object
#  17  sizes                   1000 non-null   object
#  18  videos                  219 non-null    object
#  19  seller_information      699 non-null    object
#  20  variations              438 non-null    object
#  21  best_offer              1000 non-null   object
#  22  more_offers             1000 non-null   object
#  23  category                1000 non-null   object
# dtypes: float64(2), int64(3), object(19)
# memory usage: 187.6+ KB

# %%
#statistical summary of the data 
# mean,mediam,standard deviation,min,max and Quartiles
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
#categorical columns summary
# top frequent values, unique values and also counts 
df.describe(include='object')
# Out:
#            title   product_description final_price currency  \
# count       1000                  1000        1000     1000
# unique       454                   989         466        1
# top     Roadster  Women Pink Solid Top   "₹999.00"      INR
# freq          30                     3          25     1000
#
#                                                    images  \
# count                                                1000
# unique                                               1000
# top     http://assets.myntassets.com/assets/images/837...
# freq                                                    1
#
#                                          delivery_options  \
# count                                                1000
# unique                                                 16
# top     ["100% Original Products","Pay on delivery mig...
# freq                                                  650
#
#                                           product_details  \
# count                                                1000
# unique                                                998
# top     {"description":"A pair of navy blue running sp...
# freq                                                    2
#
#                                               breadcrumbs  \
# count                                                1000
# unique                                                658
# top     [{"name":"Clothing","url":"https://www.myntra....
# freq                                                   16
#
#                                    product_specifications  \
# count                                                1000
# unique                                                967
# top     [{"specification_name":"Blouse","specification...
# freq                                                    4
#
#                                           amount_of_stars  \
# count                                                1000
# unique                                                808
# top     {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# freq                                                  114
#
#                                       what_customers_said   seller_name  \
# count                                                 427           699
# unique                                                302           301
# top     [{"percentage":"100","value_name":"Fit, Just R...  Sup███om ███
# freq                                                   27            40
#
#                        sizes                 videos  \
# count                   1000                    219
# unique                   672                    219
# top     [{"size":"Onesize"}]  ["rw-8376765_cae700"]
# freq                     135                      1
#
#                                        seller_information variations  \
# count                                                 699        438
# unique                                                298         22
# top     Plo███o- ███ 1s█████████Sui███████████████████...       [{}]
# freq                                                   40        126
#
#        best_offer                                        more_offers category
# count        1000                                               1000     1000
# unique        468                                                159       97
# top            {}  [{"offer_name":"10% Instant Discount on IndusI...     tops
# freq          306                                                265      122

# %%
#columns from the dataset
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
#data type of each column from the dataset
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# Handling Missing Values

# %%
#handling missing values
#missing values in each column
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
'''
the columns having null values are discount,what_customers_said, 
seller_name,videos ,seller_information and variantions
# %of missing values of discount =12.1%
# %of missing values of what_customers_said= 57.3%
# %of missing values of seller_name=30.1%
# %of missing values of videos=78.1%
# %of missing values of seller_infomation=30.1%
# %of missing values of variations=56.2
 '''

#filling null data
#filling discount with median
df["discount"] = df["discount"].fillna(df["discount"].median())
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                    0
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
#seller_columns non null values
print(df["seller_name"].sample(10))
# Out:
# 80                       Sup███om ███
# 153                Sle███ Ap███els███
# 117             Ape███ppa███s -██████
# 356                               NaN
# 491    HOU███OF ███NDS█████████LLP███
# 260          TRA███LA ███OM █████████
# 33           V S███ CR███ION█████████
# 321                               NaN
# 801                               NaN
# 742                               NaN
# Name: seller_name, dtype: object

# %%
#handling missing value of seller_name
df["seller_name"] = df["seller_name"].fillna("Unknown Seller")
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                    0
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name                 0
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
#displaying seller_information column
print(df["seller_information"].sample(10))
# Out:
# 496    C-1███ Ba███ent█████████Col███████████████████...
# 1                                                    NaN
# 210    9/1███, S███et █████████ula███████████████████...
# 347    10T███LOO███DU █████████ITY███████████████████...
# 37     BLD███NO.███BAS█████████VAI███████████████████...
# 828    Plo███o- ███ 1s█████████Sui███████████████████...
# 577    1 s███loo███Cab█████████-01███████████████████...
# 844                                                  NaN
# 316    Blo███B-1███abi█████████-24███████████████████...
# 856                                                  NaN
# Name: seller_information, dtype: object

# %%
#handling missing values for seller_information
df["seller_information"] = df["seller_information"].fillna("Information not Found")
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                    0
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name                 0
# sizes                       0
# videos                    781
# seller_information          0
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
#display sample data of what_customer_said column
print(df['what_customers_said'].dtype) #object

#example data 
print(df[df["what_customers_said"].notna()]["what_customers_said"])
# Out:
# object
# 23     [{"percentage":"100","value_name":"Fit, Just R...
# 42     [{"percentage":"100","value_name":"Fit, Just R...
# 46     [{"percentage":"40","value_name":"Fit, A Littl...
# 48     [{"percentage":"100","value_name":"Fit, Just R...
# 51     [{"percentage":"70","value_name":"Fit, Just Ri...
#                              ...
# 966    [{"percentage":"96","value_name":"Fit, Just Ri...
# 968    [{"percentage":"100","value_name":"Fit, A Litt...
# 969    [{"percentage":"50","value_name":"Fit, Just Ri...
# 970    [{"percentage":"67","value_name":"Fit, Just Ri...
# 971    [{"percentage":"67","value_name":"Fit, Just Ri...
# Name: what_customers_said, Length: 427, dtype: object

# %%
#despite having 50%+ null values as we cannot ignore the feedback from the customers as they are 
#core business logic 
#handling the null values by adding an indicator flag (feature engineering !!)

#creating a indicator column as has_customer_reviews
df["has_customer_reviews"]=df['what_customers_said'].notna().astype(int)

#filling the null values with an empty list to preserve sturcture
df["what_customers_said"] = df["what_customers_said"].fillna("[]")

# Verify
print(df["what_customers_said"].isnull().sum())

#view the result
df[['what_customers_said', 'has_customer_reviews']].sample(10)
# Out:
# 0
#                                    what_customers_said  has_customer_reviews
# 488                                                 []                     0
# 754  [{"percentage":"50","value_name":"Fit, Just Ri...                     1
# 101  [{"percentage":"50","value_name":"Fit, A Littl...                     1
# 956                                                 []                     0
# 713                                                 []                     0
# 529                                                 []                     0
# 321                                                 []                     0
# 621                                                 []                     0
# 351  [{"percentage":"60","value_name":"Fit, Just Ri...                     1
# 210                                                 []                     0

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                    0
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said         0
# seller_name                 0
# sizes                       0
# videos                    781
# seller_information          0
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# has_customer_reviews        0
# dtype: int64

# %%
#sample data of vide0s and variations column which are not null
print(df["videos"].sample(10))
# Out:
# 879                                                  NaN
# 758    ["https://videos.myntassets.com/assets/videos/...
# 16                                                   NaN
# 274                                                  NaN
# 869                                                  NaN
# 551                                                  NaN
# 613    ["https://videos.myntassets.com/assets/videos/...
# 573    ["https://videos.myntassets.com/assets/videos/...
# 14                                                   NaN
# 382    ["rw-18973648_cae700","https://videos.myntasse...
# Name: videos, dtype: object

# %%
#dropping videos column as doesnt effect the actual analysis of the data
df=df.drop(columns=["videos"])

#verification 
print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'has_customer_reviews'],
#       dtype='object')

# %%
#sample data of variations column
print(df["variations"].sample(10))
# Out:
# 64     [{},{},{},{}]
# 987              NaN
# 678    [{},{},{},{}]
# 5            [{},{}]
# 538          [{},{}]
# 248             [{}]
# 705          [{},{}]
# 652              NaN
# 617              NaN
# 681              NaN
# Name: variations, dtype: object

# %%
#dropping the variations column as there is no valid data
df=df.drop(columns=["variations"])

print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'seller_information', 'best_offer',
#        'more_offers', 'category', 'has_customer_reviews'],
#       dtype='object')

# %% [markdown]
# Basic Operations
