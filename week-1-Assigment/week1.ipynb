# %%
# importing pandas
import pandas as pd

pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Loading the data

# %%
#loading the data from the csv file to a data frame 
df=pd.read_csv('data.csv')

# %% [markdown]
# Exploring data

# %%
#exploring data 

#displays first 5 rows
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
#display last 5 rows
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
#random rows from the dataset 
df.sample(5)
# Out:
#      product_id        title  \
# 670    18658050  Allen Solly
# 45     21860658    EROTISSCH
# 270    13596626        Anouk
# 874    17950198      PURVAJA
# 742    19055422  Monte Carlo
#
#                                    product_description  rating  ratings_count  \
# 670                  Men Brown Printed Slim Fit Shorts     4.6             13
# 45                    Women Printed Laced Basic Briefs     0.0              0
# 270  Women Gold-Toned & Beige Embellished One Toe F...     4.3             44
# 874  Women Solid Pink Round Neck Leg of Mutton Slee...     3.4             29
# 742                               Women Black Cardigan     4.2             18
#
#      initial_price  discount  final_price currency  \
# 670           1799      40.0  "₹1,079.00"      INR
# 45             899      40.0    "₹539.00"      INR
# 270           2299       NaN  "₹2,299.00"      INR
# 874           2199      81.0  "₹2,199.00"      INR
# 742           2080      40.0  "₹2,080.00"      INR
#
# ...

# %%
# no of rows and columns in the data set
df.shape
# Out:
# (1000, 24)

# %%
#structural summary of the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   object
#  2   product_description     1000 non-null   object
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   object
#  8   currency                1000 non-null   object
#  9   images                  1000 non-null   object
#  10  delivery_options        1000 non-null   object
#  11  product_details         1000 non-null   object
#  12  breadcrumbs             1000 non-null   object
#  13  product_specifications  1000 non-null   object
# ...

# %%
#statistical summary of the data 
# mean,mediam,standard deviation,min,max and Quartiles
df.describe()
# Out:
#          product_id     rating  ratings_count  initial_price    discount
# count  1.000000e+03  1000.0000    1000.000000     1000.00000  879.000000
# mean   1.713437e+07     3.6215      76.691000     2723.24100   53.503982
# std    3.813766e+06     1.3744     241.114263     2408.69736   18.029201
# min    5.868460e+05     0.0000       0.000000      249.00000    1.000000
# 25%    1.511501e+07     3.7000       7.000000     1399.00000   44.000000
# 50%    1.820890e+07     4.1000      17.000000     1999.00000   56.000000
# 75%    1.902737e+07     4.3000      58.000000     3299.00000   66.000000
# max    2.274707e+07     5.0000    4441.000000    22199.00000   88.000000

# %%
#categorical columns summary
# top frequent values, unique values and also counts 
df.describe(include='object')
# Out:
#            title   product_description final_price currency  \
# count       1000                  1000        1000     1000
# unique       454                   989         466        1
# top     Roadster  Women Pink Solid Top   "₹999.00"      INR
# freq          30                     3          25     1000
#
#                                                    images  \
# count                                                1000
# unique                                               1000
# top     http://assets.myntassets.com/assets/images/837...
# freq                                                    1
#
#                                          delivery_options  \
# count                                                1000
# unique                                                 16
# top     ["100% Original Products","Pay on delivery mig...
# freq                                                  650
#
#                                           product_details  \
# ...

# %%
#columns from the dataset
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
#data type of each column from the dataset
df.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# Handling Missing Values

# %%
#handling missing values
#missing values in each column
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
'''
the columns having null values are discount,what_customers_said, 
seller_name,videos ,seller_information and variantions
# %of missing values of discount =12.1%
# %of missing values of what_customers_said= 57.3%
# %of missing values of seller_name=30.1%
# %of missing values of videos=78.1%
# %of missing values of seller_infomation=30.1%
# %of missing values of variations=56.2
 '''

#filling null data
#filling discount with median
df["discount"] = df["discount"].fillna(df["discount"].median())

# %%
#seller_columns non null values
print(df["seller_name"].sample(10))
# Out:
# 112                           APE███PPA███S
# 825    MAY███I L███STY█████████E L█████████
# 34                                      NaN
# 313                            Sup███om ███
# 579       ARV███ LI███TYL█████████LIM██████
# 815                                     NaN
# 930       Wes███ry ███din█████████d_M██████
# 633                                     NaN
# 589                            Sup███om ███
# 247                            UDA███ASH███
# Name: seller_name, dtype: object

# %%
#handling missing value of seller_name
df["seller_name"] = df["seller_name"].fillna("Unknown Seller")

# %%
#displaying seller_information column
print(df["seller_information"].sample(10))
# Out:
# 337    LOW███GRO███ FL█████████ERT███████████████████...
# 478                                                  NaN
# 846                                                  NaN
# 720    1st███oor███abi█████████02,███████████████████...
# 728    Blo███B-1███abi█████████-24███████████████████...
# 95     Rel███ce ███uku█████████Ltd███████████████████...
# 988                                                  NaN
# 381    Plo███o- ███ 1s█████████Sui███████████████████...
# 502    C-1███ Ba███ent█████████Col███████████████████...
# 190    . P███ NO███1 S█████████VT ███████████████████...
# Name: seller_information, dtype: object

# %%
#handling missing values for seller_information
df["seller_information"] = df["seller_information"].fillna("Information not Found")

# %%
#display sample data of what_customer_said column
print(df['what_customers_said'].dtype) #object

#example data 
print(df[df["what_customers_said"].notna()]["what_customers_said"])
# Out:
# object
# 23     [{"percentage":"100","value_name":"Fit, Just R...
# 42     [{"percentage":"100","value_name":"Fit, Just R...
# 46     [{"percentage":"40","value_name":"Fit, A Littl...
# 48     [{"percentage":"100","value_name":"Fit, Just R...
# 51     [{"percentage":"70","value_name":"Fit, Just Ri...
#                              ...
# 966    [{"percentage":"96","value_name":"Fit, Just Ri...
# 968    [{"percentage":"100","value_name":"Fit, A Litt...
# 969    [{"percentage":"50","value_name":"Fit, Just Ri...
# 970    [{"percentage":"67","value_name":"Fit, Just Ri...
# 971    [{"percentage":"67","value_name":"Fit, Just Ri...
# Name: what_customers_said, Length: 427, dtype: object

# %%
#despite having 50%+ null values as we cannot ignore the feedback from the customers as they are 
#core business logic 
#handling the null values by adding an indicator flag (feature engineering !!)

#creating a indicator column as has_customer_reviews
df["has_customer_reviews"]=df['what_customers_said'].notna().astype(int)

#filling the null values with an empty list to preserve sturcture
df["what_customers_said"] = df["what_customers_said"].fillna("[]")

# Verify
print(df["what_customers_said"].isnull().sum())

#view the result
df[['what_customers_said', 'has_customer_reviews']].sample(10)
# Out:
# 0
#                                    what_customers_said  has_customer_reviews
# 39                                                  []                     0
# 717                                                 []                     0
# 364  [{"percentage":"100","value_name":"Fit, Just R...                     1
# 692                                                 []                     0
# 344                                                 []                     0
# 650                                                 []                     0
# 388  [{"percentage":"100","value_name":"Fit, Just R...                     1
# 741  [{"percentage":"64","value_name":"Fit, Just Ri...                     1
# 384  [{"percentage":"58","value_name":"Fit, Just Ri...                     1
# 583  [{"percentage":"72","value_name":"Fit, Just Ri...                     1

# %%
#sample data of vide0s and variations column which are not null
print(df["videos"].sample(10))
# Out:
# 789                                                  NaN
# 98                                                   NaN
# 648                                                  NaN
# 314    ["rw-16696848_cae700","https://videos.myntasse...
# 397    ["rw-18973700_cae700","https://videos.myntasse...
# 6                                                    NaN
# 240                                                  NaN
# 731                                                  NaN
# 328    ["https://videos.myntassets.com/assets/videos/...
# 891                                                  NaN
# Name: videos, dtype: object

# %%
#dropping videos column as doesnt effect the actual analysis of the data
df=df.drop(columns=["videos"])

#verification 
print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category', 'has_customer_reviews'],
#       dtype='object')

# %%
#sample data of variations column
print(df["variations"].sample(10))
# Out:
# 122       [{}]
# 924    [{},{}]
# 59         NaN
# 312    [{},{}]
# 251        NaN
# 979        NaN
# 666        NaN
# 990        NaN
# 552       [{}]
# 338    [{},{}]
# Name: variations, dtype: object

# %%
#dropping the variations column as there is no valid data
df=df.drop(columns=["variations"])

print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'seller_information', 'best_offer',
#        'more_offers', 'category', 'has_customer_reviews'],
#       dtype='object')

# %%
df.isnull().sum()
#all null values have been handled
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# seller_information        0
# best_offer                0
# more_offers               0
# category                  0
# has_customer_reviews      0
# dtype: int64

# %%
print(df['final_price'].dtype)
#final_price should be float value rather than a integer 
print(df["final_price"].sample(10))
# Out:
# object
# 66     "₹2,249.00"
# 674      "₹639.00"
# 442    "₹5,199.00"
# 106      "₹884.00"
# 349    "₹1,090.00"
# 451    "₹1,499.00"
# 167    "₹1,899.00"
# 290    "₹1,459.00"
# 374    "₹4,099.00"
# 457    "₹1,124.00"
# Name: final_price, dtype: object

# %%
#converting final_price from object to float

#removing ruppe and comma symbol
df['final_price'] = df['final_price'].astype(str).str.replace(r'[^\d.]', '', regex=True)

#converting the object value to float value
df['final_price'] = pd.to_numeric(df['final_price'],errors='coerce')

print(df["final_price"].dtype)

print(df["final_price"].sample(10))
# Out:
# float64
# 82      719.0
# 563    2199.0
# 14     1599.0
# 444    5995.0
# 236     389.0
# 207     947.0
# 416    3499.0
# 125     892.0
# 970     389.0
# 529    1319.0
# Name: final_price, dtype: float64

# %% [markdown]
# Basic Operations

# %%
#selecting columns relevent for pricing analysis
pricing_df = df[['title', 'category', 'initial_price', 'final_price']]
pricing_df.head()
# Out:
#             title   category  initial_price  final_price
# 0     Lino Perros  backpacks           3995       3995.0
# 1  Tommy Hilfiger  backpacks           2899       2899.0
# 2           Lavie  backpacks           2999       2999.0
# 3          F Gear  backpacks           1675       1675.0
# 4       MYTRIDENT  bath-robe           2899       2899.0

# %%
#filtering items to show from backpack category
backpacks_only = df[df['category'] == 'backpacks']
print(f"Number of backpacks: {backpacks_only.shape[0]}")
# Out:
# Number of backpacks: 4

# %%
#filtering for products with rating higher than 4
highly_rated = df[df['rating'] > 4.5]
highly_rated.head()
# Out:
#     product_id       title                                product_description  \
# 4     13939916   MYTRIDENT                           Men Blue Solid Bath Robe
# 7     18602872     My Room  Yellow & Green Floral 140 TC King Bedsheet wit...
# 22    21427828  London Rag               Women Stiletto Heeled High-Top Boots
# 32    18656766       VStar                            Beige Solid T-Shirt Bra
# 38    21873792   KARATCART   Cubic Zirconia Silver-Plated Wraparound Bracelet
#
#     rating  ratings_count  initial_price  discount  final_price currency  \
# 4      4.7             12           2899      17.0       2899.0      INR
# 7      4.7             10           2999      54.0       2999.0      INR
# 22     5.0              4           9599      60.0       3839.0      INR
# 32     4.6              5            345      56.0        345.0      INR
# 38     4.6              5           3397      76.0        815.0      INR
#
# ...

# %%
#products with high discount
great_deals= df[(df['discount'] > 60.0)]
great_deals.head()
# Out:
#     product_id       title                                product_description  \
# 2     17633752       Lavie                     Aries Women Pink Mini Backpack
# 6     19851824  AVI Living          Grey Solid 500 GSM Pure Cotton Bath Towel
# 11    18346118      Arrabi  Pink & White Graphic 300 TC King Bedsheet with...
# 12    18327434  BELLA CASA                              Unisex Blue Bedsheets
# 13    18492504       ROMEE  Blue & Beige Conversational 160 TC King Bedshe...
#
#     rating  ratings_count  initial_price  discount  final_price currency  \
# 2      4.4            226           2999      65.0       2999.0      INR
# 6      4.0              5           1399      65.0       1399.0      INR
# 11     0.0              0           3329      74.0        865.0      INR
# 12     0.0              0           1499      73.0        404.0      INR
# 13     3.9             10           3499      65.0       3499.0      INR
#
# ...

# %%
#title and discount for all products where discount greater than 50%
high_discount_titles = df.loc[df['discount'] > 50.0, ['title', 'discount']]
high_discount_titles.head()
# Out:
#          title  discount
# 0  Lino Perros      58.0
# 2        Lavie      65.0
# 3       F Gear      52.0
# 5          H&M      56.0
# 6   AVI Living      65.0

# %%
# Sort by rating descending
df.sort_values('rating', ascending=False).head(10)
# Out:
#      product_id           title  \
# 658    14561272           ASICS
# 437    22110424        VASTRADO
# 178    13449506          DOOR74
# 721    16864474            Puma
# 88     16185546      ellementry
# 22     21427828      London Rag
# 917    18537496  Bannos Swagger
# 52     22436508     Bruchi CLUB
# 881     9557519           MANGO
# 996    16896006           GUESS
#
#                                    product_description  rating  ratings_count  \
# 658  Court M 7In   Men Black Solid Mid-Rise Tennis ...     5.0              5
# 437  Ethnic Motifs Printed Mandarin Collar Pure Cot...     5.0              2
# 178                       Women Black Solid Maxi Dress     5.0              7
# 721        Men Orange & White Spike 22.2 Cricket Shoes     5.0              3
# 88     Gold-Toned 2 Pieces Stainless Steel Matte Spoon     5.0              5
# 22                Women Stiletto Heeled High-Top Boots     5.0              4
# ...

# %%
# Value counts for category
df['category'].value_counts()
# Out:
# category
# tops                  122
# dresses               100
# shirts                 97
# jeans                  57
# sports-shoes           51
#                      ...
# lounge-pants            1
# lounge-shorts           1
# mangalsutra             1
# mobile-accessories      1
# yoga-mats               1
# Name: count, Length: 97, dtype: int64

# %% [markdown]
# Handling Duplicates

# %%
#total number of duplicates
df.duplicated().sum()

#checking for duplicate products Ids
print(df.duplicated(subset='product_id').sum())
# Out:
# 0

# %% [markdown]
# Found 0 duplicates rows

# %% [markdown]
# Creating a dervied column as total_price

# %%
# as there is no quantity column in the dataset assuming the quantity=1
df['quantity']=1

#deriving total_amount column where 
#total_amount=final_price*quantity

df["total_amount"]=df["final_price"]*df["quantity"]

df.sample(5)
# Out:
#      product_id       title  \
# 797    18904492       Levis
# 337    22217088  DressBerry
# 997     1708108    GIORDANO
# 207    15014966    Priyaasi
# 597    17313630     JAINISH
#
#                                    product_description  rating  ratings_count  \
# 797  Women Sage Green Self Design Slim Fit Regular Top     4.4             50
# 337                           Open Back Flatform Heels     4.1             34
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...     2.8              5
# 207  Gold-Toned & Gold Plated Contemporary Jhumkas ...     4.9             13
# 597                      Men Blue Classic Formal Shirt     4.1             68
#
#      initial_price  discount  final_price currency  \
# 797           2099      20.0       1133.0      INR
# 337           1599      54.0        735.0      INR
# 997           7950      50.0       7950.0      INR
# 207           3949      76.0        947.0      INR
# 597           1999      71.0        579.0      INR
#
# ...

# %% [markdown]
# Saving the Cleaned dataset

# %%
#saving the cleaned dataset to a new csv file
df.to_csv("cleaned_data.csv",index=False)

# %%
#verifying the size
df.shape
# Out:
# (1000, 25)

# %%
#verifying the cleaned dataset
print(df.columns)
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'seller_information', 'best_offer',
#        'more_offers', 'category', 'has_customer_reviews', 'quantity',
#        'total_amount'],
#       dtype='object')
